# %% [markdown]
# <a href="https://colab.research.google.com/github/pmukeshreddy/deeplearning-basics/blob/main/hello_world_in_tensorflow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras
import numpy as np

# %%
model = keras.Sequential([keras.layers.Dense(units=1,input_shape=[1])])

# %%
model.compile(optimizer="sgd",loss="mean_squared_error")

# %%
xs  = np.array([-1.0,0.0,1.0,2.0,3.0,4.0],dtype=float)
ys = np.array([-3.0,-1.0,1.0,3.0,5.0,7.0],dtype=float)

# %%
model.fit(xs,ys,epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 1s 552ms/step - loss: 20.4602
# Epoch 2/500
# 1/1 [==============================] - 0s 8ms/step - loss: 16.3657
# Epoch 3/500
# 1/1 [==============================] - 0s 6ms/step - loss: 13.1388
# Epoch 4/500
# 1/1 [==============================] - 0s 6ms/step - loss: 10.5947
# Epoch 5/500
# 1/1 [==============================] - 0s 6ms/step - loss: 8.5877
# Epoch 6/500
# 1/1 [==============================] - 0s 6ms/step - loss: 7.0036
# Epoch 7/500
# 1/1 [==============================] - 0s 6ms/step - loss: 5.7522
# Epoch 8/500
# 1/1 [==============================] - 0s 6ms/step - loss: 4.7627
# Epoch 9/500
# 1/1 [==============================] - 0s 6ms/step - loss: 3.9793
# Epoch 10/500
# 1/1 [==============================] - 0s 7ms/step - loss: 3.3583
# Epoch 11/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.8649
# Epoch 12/500
# 1/1 [==============================] - 0s 6ms/step - loss: 2.4723
# ...

# %%
model.predict([10.0])
# Out:
# array([[18.980581]], dtype=float32)
